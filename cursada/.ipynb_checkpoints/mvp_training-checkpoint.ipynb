# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/tinch/educacionit/smoking.csv")

# %%
df.to_csv("smoking_vivo.csv")

# %%
df.sample(5, random_state=42)
# Out:
#        Unnamed: 0     ID  systolic  relaxation  Cholesterol  triglyceride  \
# 33553       33553  41917  6.000000    3.958333     8.375000      1.875000
# 9427         9427  11817  5.208333    3.125000     8.125000      2.916667
# 199           199    260  5.062688    3.167519     8.206039      4.250000
# 12447       12447  15517  5.791667    3.416667    10.625000      5.750000
# 39489       39489  49334  4.375000    2.708333     7.375000      4.375000
#
#             HDL       LDL gender   age  ...  Urine protein       ALT  \
# 33553  2.500000  5.500000      M  55.0  ...       0.041667  1.000000
# 9427   3.291667  4.250000      F  40.0  ...       0.041667  0.791667
# 199    2.333333  5.458333      F  40.0  ...       0.041667  1.250000
# 12447  2.750000  6.708333      F  50.0  ...       0.041667  0.958333
# 39489  2.583333  3.916667      F  45.0  ...       0.041667  0.583333
#
#             Gtp  dental caries  tartar  eyesight(left)  eyesight(right)  \
# 33553  2.416667              1       N        0.041667         0.041667
# 9427   0.375000              0       Y        0.006250         0.004861
# 199    0.916667              0       N        0.005556         0.004861
# 12447  0.666667              0       N        0.043056         0.043056
# 39489  0.625000              0       Y        0.041667         0.001389
#
#        hearing(left)  hearing(right)      target
# 33553       0.041667        0.041667  NO FUMADOR
# 9427        0.041667        0.041667  NO FUMADOR
# 199         0.041667        0.041667  NO FUMADOR
# 12447       0.041667        0.041667  NO FUMADOR
# 39489       0.041667        0.041667  NO FUMADOR
#
# [5 rows x 25 columns]

# %%
df = df.drop(columns=["Unnamed: 0"])

# %%
df
# Out:
#           ID  systolic  relaxation  Cholesterol  triglyceride       HDL  \
# 0          0  4.750000    3.041667     8.958333      3.416667  3.041667
# 1          1  4.958333    2.916667     8.000000      4.791667  1.750000
# 2          2  5.750000    3.583333    10.083333      7.583333  2.291667
# 3          3  4.166667    2.500000    13.416667     10.583333  1.875000
# 4          4  5.000000    3.083333     7.666667      3.083333  2.583333
# ...      ...       ...         ...          ...           ...       ...
# 49995  27343  5.062688    3.167519     8.206039      5.275309  2.625000
# 49996  27350  5.062688    3.167519     8.206039      5.275309  2.250000
# 49997  27351  5.062688    3.167519     8.206039      5.275309  1.958333
# 49998  27352  5.062688    3.167519     8.206039      5.275309  2.583333
# 49999  27354  5.062688    3.167519     8.206039      5.275309  2.750000
#
#             LDL gender   age  height(cm)  ...  Urine protein       ALT  \
# 0      5.250000      F  40.0       155.0  ...       0.041667  0.791667
# 1      5.291667      F  40.0       160.0  ...       0.041667  0.791667
# 2      6.291667      M  55.0       170.0  ...       0.041667  0.666667
# 3      9.416667      M  40.0       165.0  ...       0.041667  1.083333
# 4      4.458333      F  40.0       155.0  ...       0.041667  0.583333
# ...         ...    ...   ...         ...  ...            ...       ...
# 49995  3.041667      M  50.0       160.0  ...       0.041667  1.128868
# 49996  3.208333      M  30.0       170.0  ...       0.041667  1.128868
# 49997  2.208333      M  20.0       165.0  ...       0.041667  1.128868
# 49998  4.125000      F  60.0       160.0  ...       0.041667  1.128868
# 49999  5.041667      M  45.0       170.0  ...       0.041667  1.128868
#
#             Gtp  dental caries  tartar  eyesight(left)  eyesight(right)  \
# 0      1.125000              0       Y        0.043056         0.041667
# 1      0.750000              0       Y        0.005556         0.004167
# 2      0.916667              0       N        0.005556         0.005556
# 3      0.750000              0       Y        0.045139         0.045139
# 4      0.916667              0       N        0.041667         0.041667
# ...         ...            ...     ...             ...              ...
# 49995  0.916667              0       Y        0.004861         0.005556
# 49996  0.750000              1       Y        0.045139         0.041667
# 49997  2.916667              0       Y        0.045139         0.045139
# 49998  1.041667              1       Y        0.002778         0.002778
# 49999  2.583333              1       N        0.045139         0.041667
#
#        hearing(left) hearing(right)      target
# 0           0.041667       0.041667  NO FUMADOR
# 1           0.041667       0.041667  NO FUMADOR
# 2           0.041667       0.041667     FUMADOR
# 3           0.041667       0.041667  NO FUMADOR
# 4           0.041667       0.041667  NO FUMADOR
# ...              ...            ...         ...
# 49995       0.041667       0.042758     FUMADOR
# 49996       0.041667       0.042758     FUMADOR
# 49997       0.041667       0.042758     FUMADOR
# 49998       0.041667       0.042758  NO FUMADOR
# 49999       0.041667       0.042758     FUMADOR
#
# [50000 rows x 24 columns]

# %%
shape = df.shape

# %%
shape[1]
# Out:
# 24

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   50000 non-null  int64
#  1   systolic             50000 non-null  float64
#  2   relaxation           50000 non-null  float64
#  3   Cholesterol          50000 non-null  float64
#  4   triglyceride         50000 non-null  float64
#  5   HDL                  50000 non-null  float64
#  6   LDL                  50000 non-null  float64
#  7   gender               50000 non-null  object
#  8   age                  50000 non-null  float64
#  9   height(cm)           50000 non-null  float64
#  10  weight(kg)           50000 non-null  float64
#  11  waist(cm)            50000 non-null  float64
#  12  fasting blood sugar  50000 non-null  float64
#  13  hemoglobin           50000 non-null  float64
#  14  Urine protein        50000 non-null  float64
#  15  ALT                  50000 non-null  float64
#  16  Gtp                  50000 non-null  float64
#  17  dental caries        50000 non-null  int64
#  18  tartar               50000 non-null  object
#  19  eyesight(left)       50000 non-null  float64
#  20  eyesight(right)      50000 non-null  float64
#  21  hearing(left)        50000 non-null  float64
#  22  hearing(right)       50000 non-null  float64
#  23  target               50000 non-null  object
# dtypes: float64(19), int64(2), object(3)
# memory usage: 9.2+ MB

# %%
df.isna().sum()/df.shape[0]
# Out:
# ID                     0.0
# systolic               0.0
# relaxation             0.0
# Cholesterol            0.0
# triglyceride           0.0
# HDL                    0.0
# LDL                    0.0
# gender                 0.0
# age                    0.0
# height(cm)             0.0
# weight(kg)             0.0
# waist(cm)              0.0
# fasting blood sugar    0.0
# hemoglobin             0.0
# Urine protein          0.0
# ALT                    0.0
# Gtp                    0.0
# dental caries          0.0
# tartar                 0.0
# eyesight(left)         0.0
# eyesight(right)        0.0
# hearing(left)          0.0
# hearing(right)         0.0
# target                 0.0
# dtype: float64

# %%
desc = df.describe()

# %%
desc
# Out:
#                  ID      systolic    relaxation   Cholesterol  triglyceride  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean   26284.994580      5.062688      3.167519      8.206039      5.275309
# std    16015.070567      0.567825      0.401889      1.506033      2.980229
# min        0.000000      2.958333      1.666667      2.291667      0.333333
# 25%    12499.750000      4.666667      2.916667      7.166667      3.083333
# 50%    24999.500000      5.000000      3.166667      8.166667      4.500000
# 75%    40034.250000      5.416667      3.416667      9.125000      6.666667
# max    55690.000000     10.000000      6.083333     18.541667     41.625000
#
#                 HDL           LDL           age    height(cm)    weight(kg)  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       2.387391      4.791840     44.188155    164.646278     65.877008
# std        0.609557      1.698239     12.028283      9.172001     12.817799
# min        0.166667      0.041667     20.000000    130.000000     30.000000
# 25%        1.958333      3.833333     40.000000    160.000000     55.000000
# 50%        2.333333      4.750000     40.000000    165.000000     65.000000
# 75%        2.708333      5.625000     55.000000    170.000000     75.000000
# max       25.750000     77.500000     85.000000    190.000000    135.000000
#
#        ...  fasting blood sugar    hemoglobin  Urine protein           ALT  \
# count  ...         50000.000000  50000.000000   50000.000000  50000.000000
# mean   ...             4.138466      0.593798       0.045283      1.128868
# std    ...             0.860291      0.065770       0.016819      1.318034
# min    ...             1.916667      0.172917       0.041667      0.041667
# 25%    ...             3.708333      0.545833       0.041667      0.625000
# 50%    ...             4.000000      0.588889       0.041667      0.875000
# 75%    ...             4.291667      0.629861       0.041667      1.291667
# max    ...            21.041667      0.875694       0.250000    121.416667
#
#                 Gtp  dental caries  eyesight(left)  eyesight(right)  \
# count  50000.000000   50000.000000    50000.000000     50000.000000
# mean       1.667899       0.213120        0.028450         0.028276
# std        2.104838       0.409516        0.023898         0.023940
# min        0.041667       0.000000        0.000694         0.000694
# 25%        0.708333       0.000000        0.005556         0.005556
# 50%        1.083333       0.000000        0.041667         0.041667
# 75%        1.833333       0.000000        0.043056         0.043056
# max       41.625000       1.000000        0.381250         0.381250
#
#        hearing(left)  hearing(right)
# count   50000.000000    50000.000000
# mean        0.042737        0.042758
# std         0.006586        0.006640
# min         0.041667        0.041667
# 25%         0.041667        0.041667
# 50%         0.041667        0.041667
# 75%         0.041667        0.041667
# max         0.083333        0.083333
#
# [8 rows x 21 columns]

# %%
df.triglyceride.unique()
# Out:
# array([ 3.41666667,  4.79166667,  7.58333333, 10.58333333,  3.08333333,
#         8.29166667,  2.83333333, 11.20833333,  2.75      ,  6.125     ,
#         5.875     ,  8.20833333,  8.75      ,  1.95833333,  7.25      ,
#         2.5       ,  3.29166667, 13.25      ,  4.95833333,  2.375     ,
#         3.20833333,  3.91666667,  3.33333333,  3.16666667,  3.54166667,
#         9.08333333, 11.375     ,  9.75      ,  3.70833333,  3.75      ,
#         5.83333333, 10.20833333,  2.20833333,  2.70833333,  5.41666667,
#        10.625     ,  2.875     ,  2.54166667,  4.20833333,  6.83333333,
#         2.41666667,  4.5       ,  5.29166667,  3.625     ,  4.125     ,
#         5.        ,  3.125     ,  8.08333333,  8.41666667,  5.04166667,
#         4.54166667,  3.5       , 12.16666667,  6.16666667,  4.66666667,
#         3.875     ,  7.625     ,  3.375     ,  5.5       ,  2.95833333,
#         5.33333333,  4.04166667,  6.08333333,  4.83333333,  4.16666667,
#        12.83333333,  3.83333333,  5.125     ,  5.45833333,  2.45833333,
#         1.54166667,  5.16666667,  2.58333333,  5.79166667,  2.29166667,
#         4.375     ,  6.33333333,  2.        ,  4.58333333,  4.08333333,
#         2.08333333,  5.25      ,  6.66666667,  4.33333333,  8.125     ,
#         1.70833333,  4.91666667,  9.70833333, 15.25      ,  3.        ,
#         2.33333333,  1.20833333,  6.5       ,  1.625     , 12.125     ,
#        11.33333333, 12.54166667,  4.875     ,  6.29166667,  5.95833333,
#         9.66666667,  8.25      ,  7.        ,  3.04166667, 12.95833333,
#         5.75      , 10.95833333, 14.375     ,  9.375     ,  5.54166667,
#         9.41666667, 12.625     ,  7.41666667, 10.08333333, 10.45833333,
#         2.79166667,  6.70833333,  2.125     , 10.        ,  7.08333333,
#         7.66666667,  4.70833333,  5.70833333,  3.25      ,  9.625     ,
#        12.91666667,  4.25      ,  4.        ,  2.625     ,  3.66666667,
#         6.79166667,  8.625     ,  5.20833333,  8.58333333,  4.75      ,
#         5.375     ,  6.        , 12.20833333, 15.08333333, 13.91666667,
#         3.58333333,  9.91666667,  7.83333333,  1.79166667,  3.45833333,
#        12.75      , 10.66666667,  1.875     ,  4.29166667,  5.91666667,
#         7.33333333,  4.45833333,  7.375     ,  2.66666667,  5.625     ,
#        14.58333333,  2.16666667,  8.66666667,  4.625     ,  6.95833333,
#         5.66666667,  2.04166667,  9.04166667,  7.20833333,  6.91666667,
#         8.04166667, 11.08333333, 13.79166667,  3.79166667, 11.5       ,
#         7.75      ,  7.79166667,  7.91666667, 11.16666667,  7.54166667,
#         5.08333333,  6.41666667,  5.58333333,  6.45833333, 11.625     ,
#        13.75      , 13.70833333,  6.625     ,  1.91666667,  1.83333333,
#         7.70833333,  8.83333333,  3.95833333,  7.04166667, 14.        ,
#         1.5       ,  1.41666667, 15.        , 11.70833333,  9.33333333,
#         7.29166667, 12.5       , 11.95833333, 15.79166667,  9.25      ,
#         9.20833333,  9.58333333, 11.25      ,  8.45833333, 10.125     ,
#         6.375     ,  9.83333333,  6.04166667,  1.125     ,  2.91666667,
#        10.83333333,  6.54166667,  9.125     ,  1.66666667,  2.25      ,
#         8.91666667, 11.125     ,  7.125     ,  6.875     ,  6.20833333,
#        12.41666667,  1.33333333, 11.66666667,  6.58333333,  8.33333333,
#         6.75      , 16.33333333, 13.125     ,  7.16666667,  9.95833333,
#         7.875     , 10.04166667,  1.16666667, 10.41666667, 11.04166667,
#         8.16666667, 10.25      ,  7.45833333,  1.29166667,  1.58333333,
#        10.29166667, 16.625     ,  0.875     ,  9.        , 15.04166667,
#         8.5       , 10.875     ,  4.41666667, 16.08333333, 15.95833333,
#         7.95833333, 13.29166667, 12.04166667,  9.54166667,  9.29166667,
#        11.58333333, 10.54166667,  1.45833333,  7.5       ,  9.45833333,
#         1.75      ,  6.25      ,  9.79166667, 11.45833333,  8.79166667,
#        10.375     , 12.29166667, 10.91666667, 14.75      ,  9.875     ,
#         9.16666667, 10.75      , 11.29166667,  8.875     , 12.08333333,
#        10.5       ,  8.54166667, 11.        , 12.        ,  8.70833333,
#         9.5       , 10.79166667, 13.5       , 14.04166667,  1.375     ,
#        11.41666667, 15.58333333, 10.33333333, 12.25      , 13.375     ,
#         8.375     ,  8.        , 15.45833333, 11.875     , 13.54166667,
#        11.91666667, 13.58333333, 13.95833333, 10.70833333, 15.66666667,
#        13.04166667, 11.83333333, 10.16666667, 14.20833333, 11.75      ,
#        13.66666667, 16.41666667, 15.5       , 15.41666667, 14.45833333,
#        16.125     ,  1.08333333, 14.66666667, 12.79166667, 12.45833333,
#        12.66666667, 15.16666667, 13.33333333, 16.29166667, 13.83333333,
#        14.70833333, 14.16666667,  1.        ,  8.95833333, 15.625     ,
#        13.08333333, 14.29166667, 16.45833333, 11.54166667, 12.58333333,
#        12.33333333, 16.54166667, 15.91666667,  0.79166667, 14.5       ,
#        15.70833333, 14.08333333, 16.04166667,  0.95833333, 14.41666667,
#        16.        , 16.375     , 15.375     , 16.16666667, 15.125     ,
#        15.83333333, 11.79166667, 14.875     , 12.875     , 14.54166667,
#        16.58333333, 14.91666667, 12.70833333, 15.33333333,  1.25      ,
#        13.625     , 14.33333333, 16.5       , 15.875     ,  0.83333333,
#        13.41666667, 16.25      , 15.29166667, 13.16666667,  0.91666667,
#        15.75      , 14.25      , 16.20833333, 41.625     , 14.95833333,
#        13.45833333, 14.79166667, 13.875     , 14.625     , 13.20833333,
#        13.        , 15.20833333, 14.125     , 14.83333333,  1.04166667,
#         0.33333333, 15.54166667, 12.375     ,  0.66666667, 16.875     ,
#        22.83333333, 18.        , 19.41666667,  0.45833333,  0.625     ,
#         5.27530896])

# %% [markdown]
# #### Variable "target"

# %%
df.target.nunique()
# Out:
# 2

# %%
target_counts = df["target"].value_counts()

# %%
target_counts
# Out:
# target
# NO FUMADOR    31671
# FUMADOR       18329
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.pie(target_counts, labels=target_counts.index, startangle=90)
plt.title("Distribucion de la variable target")
plt.show()

# %% [markdown]
# #### Histograma + KDE

# %%
numeric_columns = ["systolic","age","Cholesterol","triglyceride"]

# %%
for col in numeric_columns:
    plt.figure(figsize=(10,8))
    sns.histplot(df[col], kde=True, color="salmon")
    plt.title(f"Histograma y kde para la variable{col}")
    plt.show()

# %%
sns.histplot(np.log(df[col]), kde=True)
# Out:
# <Axes: xlabel='triglyceride', ylabel='Count'>

# %%
for col in numeric_columns:
    plt.figure(figsize=(10,8))
    sns.boxplot(df[col])
    plt.title(f"Boxplot para la variable {col}")
    plt.show()

# %% [markdown]
# #### Histogramas vs target

# %%
for col in numeric_columns:
    plt.figure(figsize=(10,6))
    sns.histplot(data = df, x = col, hue = "target", kde=True, element = "step", stat="density", common_norm=False)
    plt.title(f'Histograma y densidad de la variable {col}')
    plt.show()

# %% [markdown]
# #### Scatterplots

# %%
variables_a_comparar = [("Cholesterol","triglyceride")]

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="Cholesterol",y="triglyceride", hue="target", data=df)
plt.title("Scatterplot entre Cholesterol y triglyceride")
plt.show()

# %% [markdown]
# #### Tratamiento de outliers

# %%
for col in numeric_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 -  Q1

    lower_bound = Q1 - 1.5 * IQR 
    upper_bound = Q3 + 1.5 * IQR

    col_mean = df[col].mean()

    df.loc[(df[col] < lower_bound) | (df[col] > upper_bound), col] = col_mean

# %%
for col in numeric_columns:
    plt.figure(figsize=(10,6))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot de {col}')
    plt.show()

# %%
df.describe()
# Out:
#                  ID      systolic    relaxation   Cholesterol  triglyceride  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean   26284.994580      5.041876      3.167519      8.157944      4.925135
# std    16015.070567      0.524919      0.401889      1.405955      2.371398
# min        0.000000      3.583333      1.666667      4.250000      0.333333
# 25%    12499.750000      4.666667      2.916667      7.166667      3.083333
# 50%    24999.500000      5.000000      3.166667      8.166667      4.500000
# 75%    40034.250000      5.416667      3.416667      9.083333      6.166667
# max    55690.000000      6.541667      6.083333     12.041667     12.041667
#
#                 HDL           LDL           age    height(cm)    weight(kg)  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       2.387391      4.791840     43.994087    164.646278     65.877008
# std        0.609557      1.698239     11.731783      9.172001     12.817799
# min        0.166667      0.041667     20.000000    130.000000     30.000000
# 25%        1.958333      3.833333     40.000000    160.000000     55.000000
# 50%        2.333333      4.750000     40.000000    165.000000     65.000000
# 75%        2.708333      5.625000     50.000000    170.000000     75.000000
# max       25.750000     77.500000     75.000000    190.000000    135.000000
#
#        ...  fasting blood sugar    hemoglobin  Urine protein           ALT  \
# count  ...         50000.000000  50000.000000   50000.000000  50000.000000
# mean   ...             4.138466      0.593798       0.045283      1.128868
# std    ...             0.860291      0.065770       0.016819      1.318034
# min    ...             1.916667      0.172917       0.041667      0.041667
# 25%    ...             3.708333      0.545833       0.041667      0.625000
# 50%    ...             4.000000      0.588889       0.041667      0.875000
# 75%    ...             4.291667      0.629861       0.041667      1.291667
# max    ...            21.041667      0.875694       0.250000    121.416667
#
#                 Gtp  dental caries  eyesight(left)  eyesight(right)  \
# count  50000.000000   50000.000000    50000.000000     50000.000000
# mean       1.667899       0.213120        0.028450         0.028276
# std        2.104838       0.409516        0.023898         0.023940
# min        0.041667       0.000000        0.000694         0.000694
# 25%        0.708333       0.000000        0.005556         0.005556
# 50%        1.083333       0.000000        0.041667         0.041667
# 75%        1.833333       0.000000        0.043056         0.043056
# max       41.625000       1.000000        0.381250         0.381250
#
#        hearing(left)  hearing(right)
# count   50000.000000    50000.000000
# mean        0.042737        0.042758
# std         0.006586        0.006640
# min         0.041667        0.041667
# 25%         0.041667        0.041667
# 50%         0.041667        0.041667
# 75%         0.041667        0.041667
# max         0.083333        0.083333
#
# [8 rows x 21 columns]

# %% [markdown]
# #### Model training

# %%
df
# Out:
#           ID  systolic  relaxation  Cholesterol  triglyceride       HDL  \
# 0          0  4.750000    3.041667     8.958333      3.416667  3.041667
# 1          1  4.958333    2.916667     8.000000      4.791667  1.750000
# 2          2  5.750000    3.583333    10.083333      7.583333  2.291667
# 3          3  4.166667    2.500000     8.206039     10.583333  1.875000
# 4          4  5.000000    3.083333     7.666667      3.083333  2.583333
# ...      ...       ...         ...          ...           ...       ...
# 49995  27343  5.062688    3.167519     8.206039      5.275309  2.625000
# 49996  27350  5.062688    3.167519     8.206039      5.275309  2.250000
# 49997  27351  5.062688    3.167519     8.206039      5.275309  1.958333
# 49998  27352  5.062688    3.167519     8.206039      5.275309  2.583333
# 49999  27354  5.062688    3.167519     8.206039      5.275309  2.750000
#
#             LDL gender   age  height(cm)  ...  Urine protein       ALT  \
# 0      5.250000      F  40.0       155.0  ...       0.041667  0.791667
# 1      5.291667      F  40.0       160.0  ...       0.041667  0.791667
# 2      6.291667      M  55.0       170.0  ...       0.041667  0.666667
# 3      9.416667      M  40.0       165.0  ...       0.041667  1.083333
# 4      4.458333      F  40.0       155.0  ...       0.041667  0.583333
# ...         ...    ...   ...         ...  ...            ...       ...
# 49995  3.041667      M  50.0       160.0  ...       0.041667  1.128868
# 49996  3.208333      M  30.0       170.0  ...       0.041667  1.128868
# 49997  2.208333      M  20.0       165.0  ...       0.041667  1.128868
# 49998  4.125000      F  60.0       160.0  ...       0.041667  1.128868
# 49999  5.041667      M  45.0       170.0  ...       0.041667  1.128868
#
#             Gtp  dental caries  tartar  eyesight(left)  eyesight(right)  \
# 0      1.125000              0       Y        0.043056         0.041667
# 1      0.750000              0       Y        0.005556         0.004167
# 2      0.916667              0       N        0.005556         0.005556
# 3      0.750000              0       Y        0.045139         0.045139
# 4      0.916667              0       N        0.041667         0.041667
# ...         ...            ...     ...             ...              ...
# 49995  0.916667              0       Y        0.004861         0.005556
# 49996  0.750000              1       Y        0.045139         0.041667
# 49997  2.916667              0       Y        0.045139         0.045139
# 49998  1.041667              1       Y        0.002778         0.002778
# 49999  2.583333              1       N        0.045139         0.041667
#
#        hearing(left) hearing(right)      target
# 0           0.041667       0.041667  NO FUMADOR
# 1           0.041667       0.041667  NO FUMADOR
# 2           0.041667       0.041667     FUMADOR
# 3           0.041667       0.041667  NO FUMADOR
# 4           0.041667       0.041667  NO FUMADOR
# ...              ...            ...         ...
# 49995       0.041667       0.042758     FUMADOR
# 49996       0.041667       0.042758     FUMADOR
# 49997       0.041667       0.042758     FUMADOR
# 49998       0.041667       0.042758  NO FUMADOR
# 49999       0.041667       0.042758     FUMADOR
#
# [50000 rows x 24 columns]

# %%
[]

# %%
df["target"] = df["target"].map({"FUMADOR": 1, "NO FUMADOR":0})

# %%
df["tartar"] = df["tartar"].map({"Y": 1, "N":0})

# %%
df["gender"] = df["gender"].map({"F": 1, "M":0})

# %%
df
# Out:
#           ID  systolic  relaxation  Cholesterol  triglyceride       HDL  \
# 0          0  4.750000    3.041667     8.958333      3.416667  3.041667
# 1          1  4.958333    2.916667     8.000000      4.791667  1.750000
# 2          2  5.750000    3.583333    10.083333      7.583333  2.291667
# 3          3  4.166667    2.500000     8.206039     10.583333  1.875000
# 4          4  5.000000    3.083333     7.666667      3.083333  2.583333
# ...      ...       ...         ...          ...           ...       ...
# 49995  27343  5.062688    3.167519     8.206039      5.275309  2.625000
# 49996  27350  5.062688    3.167519     8.206039      5.275309  2.250000
# 49997  27351  5.062688    3.167519     8.206039      5.275309  1.958333
# 49998  27352  5.062688    3.167519     8.206039      5.275309  2.583333
# 49999  27354  5.062688    3.167519     8.206039      5.275309  2.750000
#
#             LDL  gender   age  height(cm)  ...  Urine protein       ALT  \
# 0      5.250000       1  40.0       155.0  ...       0.041667  0.791667
# 1      5.291667       1  40.0       160.0  ...       0.041667  0.791667
# 2      6.291667       0  55.0       170.0  ...       0.041667  0.666667
# 3      9.416667       0  40.0       165.0  ...       0.041667  1.083333
# 4      4.458333       1  40.0       155.0  ...       0.041667  0.583333
# ...         ...     ...   ...         ...  ...            ...       ...
# 49995  3.041667       0  50.0       160.0  ...       0.041667  1.128868
# 49996  3.208333       0  30.0       170.0  ...       0.041667  1.128868
# 49997  2.208333       0  20.0       165.0  ...       0.041667  1.128868
# 49998  4.125000       1  60.0       160.0  ...       0.041667  1.128868
# 49999  5.041667       0  45.0       170.0  ...       0.041667  1.128868
#
#             Gtp  dental caries  tartar  eyesight(left)  eyesight(right)  \
# 0      1.125000              0       1        0.043056         0.041667
# 1      0.750000              0       1        0.005556         0.004167
# 2      0.916667              0       0        0.005556         0.005556
# 3      0.750000              0       1        0.045139         0.045139
# 4      0.916667              0       0        0.041667         0.041667
# ...         ...            ...     ...             ...              ...
# 49995  0.916667              0       1        0.004861         0.005556
# 49996  0.750000              1       1        0.045139         0.041667
# 49997  2.916667              0       1        0.045139         0.045139
# 49998  1.041667              1       1        0.002778         0.002778
# 49999  2.583333              1       0        0.045139         0.041667
#
#        hearing(left)  hearing(right)  target
# 0           0.041667        0.041667       0
# 1           0.041667        0.041667       0
# 2           0.041667        0.041667       1
# 3           0.041667        0.041667       0
# 4           0.041667        0.041667       0
# ...              ...             ...     ...
# 49995       0.041667        0.042758       1
# 49996       0.041667        0.042758       1
# 49997       0.041667        0.042758       1
# 49998       0.041667        0.042758       0
# 49999       0.041667        0.042758       1
#
# [50000 rows x 24 columns]

# %%
X = df.drop(columns=["ID","target"])
y = df["target"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, stratify=y)

# %%
X_train
# Out:
#        systolic  relaxation  Cholesterol  triglyceride       HDL       LDL  \
# 13338  4.958333    3.041667    10.500000      4.375000  2.387391  4.791840
# 47367  5.416667    2.666667     4.625000      8.291667  1.375000  1.583333
# 16711  5.416667    3.750000     5.500000      7.666667  2.000000  1.958333
# 20400  5.416667    3.750000     7.000000      2.041667  2.375000  4.208333
# 28847  5.375000    3.625000     9.208333     10.458333  2.666667  4.416667
# ...         ...         ...          ...           ...       ...       ...
# 41853  5.375000    3.458333     7.666667      4.458333  2.041667  4.750000
# 27005  5.000000    2.916667     7.541667      6.375000  2.125000  4.166667
# 45156  5.666667    4.083333     8.791667      5.416667  2.458333  5.958333
# 12291  5.062688    5.000000     7.041667      8.875000  1.791667  3.458333
# 45146  4.833333    3.000000     7.291667      2.875000  3.041667  3.666667
#
#        gender   age  height(cm)  weight(kg)  ...  hemoglobin  Urine protein  \
# 13338       1  50.0       150.0        60.0  ...    0.461111       0.041667
# 47367       0  65.0       160.0        55.0  ...    0.584722       0.208333
# 16711       0  50.0       165.0        80.0  ...    0.625000       0.041667
# 20400       0  30.0       175.0        65.0  ...    0.625694       0.041667
# 28847       0  45.0       170.0        65.0  ...    0.671528       0.041667
# ...       ...   ...         ...         ...  ...         ...            ...
# 41853       0  30.0       160.0        65.0  ...    0.666667       0.041667
# 27005       1  45.0       155.0        75.0  ...    0.545139       0.041667
# 45156       0  45.0       170.0        65.0  ...    0.546528       0.041667
# 12291       0  30.0       165.0        95.0  ...    0.669444       0.041667
# 45146       0  30.0       160.0        50.0  ...    0.666667       0.041667
#
#             ALT       Gtp  dental caries  tartar  eyesight(left)  \
# 13338  0.708333  0.416667              0       1        0.006250
# 47367  2.583333  5.125000              0       0        0.004861
# 16711  2.333333  9.708333              0       1        0.041667
# 20400  0.666667  0.750000              1       1        0.045139
# 28847  1.041667  4.416667              0       0        0.041667
# ...         ...       ...            ...     ...             ...
# 41853  2.583333  1.375000              1       1        0.043056
# 27005  1.208333  3.000000              0       0        0.043056
# 45156  0.833333  1.291667              1       0        0.005556
# 12291  2.458333  5.875000              0       1        0.043056
# 45146  0.458333  0.750000              1       1        0.006250
#
#        eyesight(right)  hearing(left)  hearing(right)
# 13338         0.045139       0.041667        0.041667
# 47367         0.003472       0.041667        0.083333
# 16711         0.041667       0.041667        0.041667
# 20400         0.043056       0.041667        0.041667
# 28847         0.045139       0.041667        0.041667
# ...                ...            ...             ...
# 41853         0.043056       0.041667        0.041667
# 27005         0.043056       0.041667        0.041667
# 45156         0.005556       0.041667        0.041667
# 12291         0.043056       0.041667        0.041667
# 45146         0.041667       0.041667        0.041667
#
# [35000 rows x 22 columns]

# %%
y_test
# Out:
# 7654     0
# 1182     0
# 32484    1
# 26451    1
# 15110    0
#         ..
# 39122    0
# 24796    0
# 45892    0
# 46384    1
# 40109    0
# Name: target, Length: 15000, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
decision_tree = DecisionTreeClassifier().fit(X_train,y_train)

# %%
decision_tree
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
y_pred_train_dt = decision_tree.predict(X_train)
y_pred_test_dt = decision_tree.predict(X_test)

# %%
df.describe()
# Out:
#                  ID      systolic    relaxation   Cholesterol  triglyceride  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean   26284.994580      5.041876      3.167519      8.157944      4.925135
# std    16015.070567      0.524919      0.401889      1.405955      2.371398
# min        0.000000      3.583333      1.666667      4.250000      0.333333
# 25%    12499.750000      4.666667      2.916667      7.166667      3.083333
# 50%    24999.500000      5.000000      3.166667      8.166667      4.500000
# 75%    40034.250000      5.416667      3.416667      9.083333      6.166667
# max    55690.000000      6.541667      6.083333     12.041667     12.041667
#
#                 HDL           LDL        gender           age    height(cm)  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       2.387391      4.791840      0.364480     43.994087    164.646278
# std        0.609557      1.698239      0.481289     11.731783      9.172001
# min        0.166667      0.041667      0.000000     20.000000    130.000000
# 25%        1.958333      3.833333      0.000000     40.000000    160.000000
# 50%        2.333333      4.750000      0.000000     40.000000    165.000000
# 75%        2.708333      5.625000      1.000000     50.000000    170.000000
# max       25.750000     77.500000      1.000000     75.000000    190.000000
#
#        ...  Urine protein           ALT           Gtp  dental caries  \
# count  ...   50000.000000  50000.000000  50000.000000   50000.000000
# mean   ...       0.045283      1.128868      1.667899       0.213120
# std    ...       0.016819      1.318034      2.104838       0.409516
# min    ...       0.041667      0.041667      0.041667       0.000000
# 25%    ...       0.041667      0.625000      0.708333       0.000000
# 50%    ...       0.041667      0.875000      1.083333       0.000000
# 75%    ...       0.041667      1.291667      1.833333       0.000000
# max    ...       0.250000    121.416667     41.625000       1.000000
#
#              tartar  eyesight(left)  eyesight(right)  hearing(left)  \
# count  50000.000000    50000.000000     50000.000000   50000.000000
# mean       0.555780        0.028450         0.028276       0.042737
# std        0.496884        0.023898         0.023940       0.006586
# min        0.000000        0.000694         0.000694       0.041667
# 25%        0.000000        0.005556         0.005556       0.041667
# 50%        1.000000        0.041667         0.041667       0.041667
# 75%        1.000000        0.043056         0.043056       0.041667
# max        1.000000        0.381250         0.381250       0.083333
#
#        hearing(right)        target
# count    50000.000000  50000.000000
# mean         0.042758      0.366580
# std          0.006640      0.481875
# min          0.041667      0.000000
# 25%          0.041667      0.000000
# 50%          0.041667      0.000000
# 75%          0.041667      1.000000
# max          0.083333      1.000000
#
# [8 rows x 24 columns]

# %%
print("training")
print(classification_report(y_train, y_pred_train_dt))
print("-----------------------------------------------")
print("testing")
print(classification_report(y_test, y_pred_test_dt))
# Out:
# training
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     22188
#            1       1.00      1.00      1.00     12812
#
#     accuracy                           1.00     35000
#    macro avg       1.00      1.00      1.00     35000
# weighted avg       1.00      1.00      1.00     35000
#
# -----------------------------------------------
# testing
#               precision    recall  f1-score   support
#
#            0       0.78      0.79      0.79      9483
#            1       0.63      0.63      0.63      5517
#
#     accuracy                           0.73     15000
#    macro avg       0.71      0.71      0.71     15000
# weighted avg       0.73      0.73      0.73     15000

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_train_knn = knn.predict(X_train_scaled)
y_pred_test_knn = knn.predict(X_test_scaled)

# %%
print("Training")
print(classification_report(y_train, y_pred_train_knn))
print("---------------------------------------------------------")
print("Test")
print(classification_report(y_test, y_pred_test_knn))
# Out:
# Training
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86     22170
#            1       0.75      0.75      0.75     12830
#
#     accuracy                           0.82     35000
#    macro avg       0.80      0.80      0.80     35000
# weighted avg       0.82      0.82      0.82     35000
#
# ---------------------------------------------------------
# Test
#               precision    recall  f1-score   support
#
#            0       0.78      0.79      0.78      9501
#            1       0.63      0.61      0.62      5499
#
#     accuracy                           0.72     15000
#    macro avg       0.70      0.70      0.70     15000
# weighted avg       0.72      0.72      0.72     15000
